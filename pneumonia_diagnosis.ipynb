# %% [markdown]
# # Pneumonia Diagnosis from chest X-ray

# %% [markdown]
# CNN classiffication with Keras.
# Diagnose pneumonia from chest x-ray

# %% [markdown]
# ## Import libraries

# %%
import tensorflow as tf
import numpy as np
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Activation, Dropout

import matplotlib.pyplot as plt
import seaborn as sn

from sklearn.metrics import roc_curve, auc, confusion_matrix
# try scikit learn metrics and grid search functions...

# %% [markdown]
# ## Create Image Data Generator from directory

# %%
# Data path
# replace data path with inpu from yml file!
data_path = r"C:\Users\leoni\PycharmProjects\Data"
PATH = os.path.join(data_path, "chest_xray")
print(os.listdir(PATH))
# Out:
# ['test', 'train', 'val']

# %%
# train, validate, test dirs
train_dir = os.path.join(PATH, "train")
val_dir = os.path.join(PATH, "val")
test_dir = os.path.join(PATH, "test")

for d in train_dir, test_dir, val_dir:
    print(os.listdir(d))
# Out:
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']

# %%
# train
pneum_train_dir = os.path.join(train_dir, 'PNEUMONIA')
norm_train_dir = os.path.join(train_dir, 'NORMAL')

#val (move data into train dir and use validation splits)
pneum_val_dir = os.path.join(val_dir, 'PNEUMONIA')
norm_val_dir = os.path.join(val_dir, 'NORMAL')

# test
pneum_test_dir = os.path.join(test_dir, 'PNEUMONIA')
norm_test_dir = os.path.join(test_dir, 'NORMAL')

# %%
data_dict = {'pneum_train': len(os.listdir(pneum_train_dir)),
             'norm_train': len(os.listdir(norm_train_dir)),
             'pneum_val': len(os.listdir(pneum_val_dir)),
             'norm_val': len(os.listdir(norm_val_dir)),
             'pneum_test': len(os.listdir(pneum_test_dir)),
             'norm_test': len(os.listdir(norm_test_dir))
            }

print(data_dict)
# Out:
# {'pneum_train': 3875, 'norm_train': 1341, 'pneum_val': 8, 'norm_val': 8, 'pneum_test': 390, 'norm_test': 234}

# %%
params = {'batch_size': 256,
          'epochs': 30,
          'img_h': 256,
          'img_w': 256
         }

# %%
train_image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.1) # Generator for our training data

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=params['batch_size'],
                                                          directory=train_dir,
                                                          shuffle=True,
                                                          target_size=(params['img_h'], params['img_w']),
                                                          color_mode='grayscale',
                                                          class_mode='binary',
                                                          subset='training')

val_data_gen = train_image_generator.flow_from_directory(batch_size=params['batch_size'],
                                                          directory=train_dir,
                                                          shuffle=True,
                                                          target_size=(params['img_h'], params['img_w']),
                                                          color_mode='grayscale',
                                                          class_mode='binary',
                                                          subset='validation')
# Out:
# Found 4695 images belonging to 2 classes.
# Found 521 images belonging to 2 classes.

# %%
sample_training_images, _ = next(train_data_gen)
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
# from https://www.tensorflow.org/tutorials/images/classification
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        # show grayscale image
        ax.imshow(img[:,:,0], cmap='gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    fig.savefig(r"images/xray_sample.png", format="png")
plotImages(sample_training_images[:5])

# %% [markdown]
# ## Simple CNN (with dropout)

# %%
# Architecture
# Should we add the final activation or not? # Activation('sigmoid')
cnn_1 = Sequential([Conv2D(filters=16, kernel_size=4, strides=(1, 1), padding='same', activation='relu',
                          input_shape=(params['img_h'], params['img_w'], 1)),
                    MaxPool2D(pool_size=(8, 8), strides=(8, 8), padding='same'),
                    Dropout(rate=0.2),
                    Conv2D(filters=32, kernel_size=4, strides=(1, 1), padding='same', activation='relu'),
                    MaxPool2D(pool_size=(4, 4), strides=(4, 4), padding='same'),
                    Dropout(rate=0.2),
                    Flatten(),
                    Dense(units=512, activation='relu'),
                    Dropout(rate=0.2),
                    Dense(units=1),
                   ])

# %%
#cnn_1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) 
# if sigmoind activation is used in the model
cnn_1.compile(optimizer='adam', 
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy']
             )

print(cnn_1.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,058,097
# Trainable params: 1,058,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = cnn_1.fit_generator(train_data_gen,
                              steps_per_epoch=len(train_data_gen),
                              epochs=params['epochs'],
                              validation_data=val_data_gen,
                              validation_steps=len(val_data_gen)
                             )
# Out:
# WARNING:tensorflow:From <ipython-input-12-25cfc2e9595a>:5: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 19 steps, validate for 3 steps
# Epoch 1/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.6060 - accuracy: 0.6251 - val_loss: 0.5535 - val_accuracy: 0.7620
# Epoch 2/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.4178 - accuracy: 0.8228 - val_loss: 0.3404 - val_accuracy: 0.8311
# Epoch 3/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.2525 - accuracy: 0.8880 - val_loss: 0.2711 - val_accuracy: 0.8637
# Epoch 4/30
# 19/19 [==============================] - 52s 3s/step - loss: 0.1913 - accuracy: 0.9212 - val_loss: 0.2043 - val_accuracy: 0.8887
# Epoch 5/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.1696 - accuracy: 0.9289 - val_loss: 0.1697 - val_accuracy: 0.8983
# Epoch 6/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.1426 - accuracy: 0.9431 - val_loss: 0.1695 - val_accuracy: 0.8925
# Epoch 7/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.1234 - accuracy: 0.9493 - val_loss: 0.1417 - val_accuracy: 0.9251
# Epoch 8/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.1197 - accuracy: 0.9546 - val_loss: 0.1374 - val_accuracy: 0.9251
# Epoch 9/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.1037 - accuracy: 0.9591 - val_loss: 0.1353 - val_accuracy: 0.9328
# Epoch 10/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.1064 - accuracy: 0.9578 - val_loss: 0.1298 - val_accuracy: 0.9386
# Epoch 11/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.1051 - accuracy: 0.9589 - val_loss: 0.1395 - val_accuracy: 0.9347
# Epoch 12/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.1047 - accuracy: 0.9595 - val_loss: 0.1125 - val_accuracy: 0.9443
# Epoch 13/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0926 - accuracy: 0.9629 - val_loss: 0.1106 - val_accuracy: 0.9367
# Epoch 14/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.0842 - accuracy: 0.9668 - val_loss: 0.1147 - val_accuracy: 0.9463
# Epoch 15/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0843 - accuracy: 0.9678 - val_loss: 0.1081 - val_accuracy: 0.9501
# Epoch 16/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.0868 - accuracy: 0.9655 - val_loss: 0.1326 - val_accuracy: 0.9367
# Epoch 17/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0853 - accuracy: 0.9655 - val_loss: 0.1033 - val_accuracy: 0.9405
# Epoch 18/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0828 - accuracy: 0.9683 - val_loss: 0.1199 - val_accuracy: 0.9443
# Epoch 19/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0827 - accuracy: 0.9695 - val_loss: 0.1247 - val_accuracy: 0.9463
# Epoch 20/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0805 - accuracy: 0.9693 - val_loss: 0.1433 - val_accuracy: 0.9386
# Epoch 21/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.0796 - accuracy: 0.9693 - val_loss: 0.0998 - val_accuracy: 0.9520
# Epoch 22/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0701 - accuracy: 0.9719 - val_loss: 0.0945 - val_accuracy: 0.9520
# Epoch 23/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.0687 - accuracy: 0.9736 - val_loss: 0.0974 - val_accuracy: 0.9539
# Epoch 24/30
# 19/19 [==============================] - 48s 3s/step - loss: 0.0656 - accuracy: 0.9732 - val_loss: 0.0919 - val_accuracy: 0.9520
# Epoch 25/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.0630 - accuracy: 0.9753 - val_loss: 0.1072 - val_accuracy: 0.9482
# Epoch 26/30
# 19/19 [==============================] - 2180s 115s/step - loss: 0.0673 - accuracy: 0.9736 - val_loss: 0.1003 - val_accuracy: 0.9520
# Epoch 27/30
# 19/19 [==============================] - 53s 3s/step - loss: 0.0580 - accuracy: 0.9781 - val_loss: 0.0953 - val_accuracy: 0.9559
# Epoch 28/30
# 19/19 [==============================] - 50s 3s/step - loss: 0.0578 - accuracy: 0.9776 - val_loss: 0.0901 - val_accuracy: 0.9597
# Epoch 29/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.0505 - accuracy: 0.9817 - val_loss: 0.0890 - val_accuracy: 0.9635
# Epoch 30/30
# 19/19 [==============================] - 49s 3s/step - loss: 0.0569 - accuracy: 0.9789 - val_loss: 0.0880 - val_accuracy: 0.9616

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(params['epochs'])

fig = plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
fig.savefig(r"images/Epochs_acc_and_loss.png", format="png")

# %% [markdown]
# ## Perfromance on Validation set

# %%
# Quickfix for the the Keras shuffle issue
val_data_gen.shuffle = False
val_data_gen.index_array = None

# %%
# Sigmoid function
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
# Make sure normal is 0 and Pneumonia is 1
val_data_gen.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
# Create arrays for y, y_hat and likelihoods
pred_probs = sigmoid(cnn_1.predict_generator(val_data_gen))
pred = (pred_probs > 0.5) * 1
actual = val_data_gen.classes.reshape(-1,1)

# %%
# Confusion matrix
cf = confusion_matrix(actual, pred)
fig = plt.figure(figsize = (4,3))
plt.title('Confusion Matirx')
ax = fig.gca()
sn.heatmap(cf, annot=True,fmt='g')
fig.savefig(r"images/ConfusionMatrix.png", format="png")

# %%
# ROC curve
fpr, tpr, _ = roc_curve(actual, pred_probs)
cnn_auc = auc(fpr, tpr)
fig = plt.figure()
plt.plot(fpr, tpr, 'b', label = 'RF AUC = %0.3f' % cnn_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
fig.savefig(r"images/ROC_curve.png", format="png")
